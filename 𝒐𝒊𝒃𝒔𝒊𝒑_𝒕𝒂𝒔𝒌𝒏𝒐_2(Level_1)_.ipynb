# %% [markdown]
# **Name: Sakshi Ubale**
#
# **Title: Customer Segmentation Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ***Data Collection***

# %%
df=pd.read_csv('/content/ifood_df.csv')

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df.head(10)
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
# 5  62513.0        0         1       16       520         42               98
# 6  55635.0        0         1       34       235         65              164
# 7  33454.0        1         0       32        76         10               56
# 8  30351.0        1         0       19        14          0               24
# 9   5648.0        1         1       68        28          0                6
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# ...

# %% [markdown]
# # ***Data Exploration and Cleaning***

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
header=['Income', 'Num of kids', 'Num of teens', 'Recency', 'MntWines', 'MntFruits',
       'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
       'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
       'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
       'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
       'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
       'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
       'marital_Single', 'marital_Together', 'marital_Widow',
       'education_2n Cycle', 'education_Basic', 'education_Graduation',
       'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
       'AcceptedCmpOverall']
df.columns = header

# %%
df.head(10)
# Out:
#     Income  Num of kids  Num of teens  Recency  MntWines  MntFruits  \
# 0  58138.0            0             0       58       635         88
# 1  46344.0            1             1       38        11          1
# 2  71613.0            0             0       26       426         49
# 3  26646.0            1             0       26        11          4
# 4  58293.0            1             0       94       173         43
# 5  62513.0            0             1       16       520         42
# 6  55635.0            0             1       34       235         65
# 7  33454.0            1             0       32        76         10
# 8  30351.0            1             0       19        14          0
# 9   5648.0            1             1       68        28          0
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0              546              172                88            88  ...
# ...

# %%
num_of_kids = df.index[df['Num of kids'] >= 1].tolist()
num_of_kids
# Out:
# [1,
#  3,
#  4,
#  7,
#  8,
#  9,
#  12,
#  15,
#  18,
#  20,
#  25,
#  26,
#  33,
#  35,
#  39,
#  41,
#  44,
#  45,
#  48,
#  50,
#  53,
#  56,
#  60,
#  61,
#  64,
#  67,
#  69,
#  74,
#  75,
#  76,
#  79,
#  80,
#  84,
#  85,
#  86,
#  88,
#  96,
#  97,
#  99,
#  105,
#  106,
#  108,
#  109,
#  110,
#  112,
#  113,
#  114,
#  118,
#  119,
#  121,
#  123,
#  125,
#  126,
#  127,
#  128,
#  133,
#  135,
#  136,
#  137,
#  142,
#  146,
#  149,
#  151,
#  153,
#  157,
#  158,
#  159,
#  160,
#  161,
#  165,
#  166,
#  169,
#  171,
#  173,
#  177,
#  178,
#  180,
#  181,
#  182,
#  186,
#  191,
#  193,
#  194,
#  199,
#  200,
#  202,
#  203,
#  206,
#  207,
#  210,
#  212,
#  216,
#  217,
#  219,
#  222,
#  223,
#  225,
#  228,
#  231,
#  232,
#  236,
#  237,
#  240,
#  241,
#  244,
#  245,
#  246,
#  248,
#  249,
#  250,
#  251,
#  253,
#  255,
#  257,
#  259,
#  260,
#  266,
#  270,
#  271,
#  273,
#  277,
#  279,
#  280,
#  282,
#  283,
#  286,
#  288,
#  289,
#  290,
#  296,
# ...

# %%
len(num_of_kids)
# Out:
# 929

# %%
num_of_teens = df.index[df['Num of teens'] >= 1].tolist()
num_of_teens
# Out:
# [1,
#  5,
#  6,
#  9,
#  12,
#  15,
#  17,
#  21,
#  22,
#  23,
#  25,
#  30,
#  31,
#  33,
#  34,
#  36,
#  38,
#  40,
#  45,
#  46,
#  50,
#  54,
#  56,
#  57,
#  58,
#  61,
#  62,
#  63,
#  64,
#  66,
#  67,
#  79,
#  80,
#  81,
#  83,
#  87,
#  88,
#  91,
#  92,
#  93,
#  97,
#  98,
#  101,
#  103,
#  106,
#  109,
#  111,
#  118,
#  119,
#  120,
#  121,
#  123,
#  126,
#  127,
#  128,
#  130,
#  132,
#  134,
#  137,
#  139,
#  140,
#  141,
#  143,
#  145,
#  146,
#  147,
#  149,
#  153,
#  157,
#  158,
#  161,
#  162,
#  163,
#  165,
#  166,
#  168,
#  174,
#  175,
#  177,
#  181,
#  182,
#  186,
#  187,
#  189,
#  191,
#  194,
#  195,
#  196,
#  197,
#  199,
#  200,
#  203,
#  205,
#  209,
#  211,
#  213,
#  214,
#  217,
#  218,
#  221,
#  224,
#  227,
#  230,
#  231,
#  233,
#  235,
#  240,
#  242,
#  243,
#  244,
#  245,
#  247,
#  250,
#  251,
#  253,
#  258,
#  259,
#  260,
#  261,
#  265,
#  267,
#  269,
#  270,
#  273,
#  280,
#  281,
#  285,
#  286,
#  287,
#  294,
# ...

# %%
len(num_of_teens)
# Out:
# 1066

# %%
df.head(10)
# Out:
#     Income  Num of kids  Num of teens  Recency  MntWines  MntFruits  \
# 0  58138.0            0             0       58       635         88
# 1  46344.0            1             1       38        11          1
# 2  71613.0            0             0       26       426         49
# 3  26646.0            1             0       26        11          4
# 4  58293.0            1             0       94       173         43
# 5  62513.0            0             1       16       520         42
# 6  55635.0            0             1       34       235         65
# 7  33454.0            1             0       32        76         10
# 8  30351.0            1             0       19        14          0
# 9   5648.0            1             1       68        28          0
#
#    MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0              546              172                88            88  ...
# ...

# %%
df['CustomerID'] = df.index + 1
cols = ['CustomerID'] + [col for col in df.columns if col != 'CustomerID']
df = df[cols]

# %%
df.head(10)
# Out:
#    CustomerID   Income  Num of kids  Num of teens  Recency  MntWines  \
# 0           1  58138.0            0             0       58       635
# 1           2  46344.0            1             1       38        11
# 2           3  71613.0            0             0       26       426
# 3           4  26646.0            1             0       26        11
# 4           5  58293.0            1             0       94       173
# 5           6  62513.0            0             1       16       520
# 6           7  55635.0            0             1       34       235
# 7           8  33454.0            1             0       32        76
# 8           9  30351.0            1             0       19        14
# 9          10   5648.0            1             1       68        28
#
#    MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# 0         88              546              172                88  ...
# ...

# %%
selected = ['Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds','MntTotal', 'MntRegularProds', 'NumDealsPurchases',
            'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']
data=df[selected]

# %%
data.head(10)
# Out:
#    Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0       58       635         88              546              172
# 1       38        11          1                6                2
# 2       26       426         49              127              111
# 3       26        11          4               20               10
# 4       94       173         43              118               46
# 5       16       520         42               98                0
# 6       34       235         65              164               50
# 7       32        76         10               56                3
# 8       19        14          0               24                3
# 9       68        28          0                6                1
#
#    MntSweetProducts  MntGoldProds  MntTotal  MntRegularProds  \
# 0                88            88      1529             1441
# 1                 1             6        21               15
# ...

# %%
data.shape
# Out:
# (2205, 13)

# %%
plt.figure(figsize=(12, 8))
num_rows = 5
num_cols = 3

for i, column in enumerate(selected, 1):
    plt.subplot(num_rows, num_cols, i)
    sns.boxplot(y=data[column],palette='viridis')
    plt.title(f'Box Plot of {column}')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-a7a5df84ae7a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[column],palette='viridis')
# <ipython-input-19-a7a5df84ae7a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[column],palette='viridis')
# <ipython-input-19-a7a5df84ae7a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=data[column],palette='viridis')
# <ipython-input-19-a7a5df84ae7a>:7: FutureWarning:
#
# ...

# %% [markdown]
# # ***Descriptive Statistics***

# %%
data.describe()
# Out:
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2205.000000  2205.000000  2205.000000      2205.000000
# mean     49.009070   306.164626    26.403175       165.312018
# std      28.932111   337.493839    39.784484       217.784507
# min       0.000000     0.000000     0.000000         0.000000
# 25%      24.000000    24.000000     2.000000        16.000000
# 50%      49.000000   178.000000     8.000000        68.000000
# 75%      74.000000   507.000000    33.000000       232.000000
# max      99.000000  1493.000000   199.000000      1725.000000
#
#        MntFishProducts  MntSweetProducts  MntGoldProds     MntTotal  \
# count      2205.000000       2205.000000   2205.000000  2205.000000
# mean         37.756463         27.128345     44.057143   562.764626
# std          54.824635         41.130468     51.736211   575.936911
# min           0.000000          0.000000      0.000000     4.000000
# ...

# %%
frequency = data[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']].count()

frequency_data = frequency.reset_index()
frequency_data.columns = ['Product Category', 'Frequency of Purchases']

frequency_data
# Out:
#    Product Category  Frequency of Purchases
# 0          MntWines                    2205
# 1         MntFruits                    2205
# 2   MntMeatProducts                    2205
# 3   MntFishProducts                    2205
# 4  MntSweetProducts                    2205
# 5      MntGoldProds                    2205

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc_df=sc.fit_transform(data)

# %%
sc_df
# Out:
# array([[ 0.31083003,  0.97456584,  1.54861372, ...,  1.42477184,
#          2.62852614, -0.5626499 ],
#        [-0.38060021, -0.8747762 , -0.63866448, ..., -1.13295709,
#         -0.58804297, -1.17973173],
#        [-0.79545835,  0.3551548 ,  0.5681097 , ...,  1.42477184,
#         -0.2306464 ,  1.2885956 ],
#        ...,
#        [ 1.45168993,  1.78365298,  0.54296857, ..., -0.76756724,
#          0.12675017,  2.21421835],
#        [-1.41774556,  0.36108218,  0.09042825, ...,  0.69399214,
#          0.8415433 ,  1.2885956 ],
#        [-0.31145718, -0.6584269 , -0.58838223, ..., -0.4021774 ,
#         -0.58804297, -0.5626499 ]])

# %% [markdown]
# # ***Customer Segmentation***

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)
pca
# Out:
# PCA(n_components=2)

# %%
p_df=pca.fit_transform(sc_df)

# %%
p_df
# Out:
# array([[ 4.82741325, -0.43851246],
#        [-2.68372663, -0.61513288],
#        [ 1.39691763,  0.15630771],
#        ...,
#        [ 1.99136827, -0.18868646],
#        [ 1.59304685,  0.35317397],
#        [-1.96342372,  0.25825981]])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(p_df)
    # Append inertia value to wcss within the loop
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss, marker='*', c='black')
plt.title('Elbow graph')
plt.xlabel('cluster')
plt.ylabel('WCSS')
plt.show()

# %%
km1=KMeans(n_clusters=5,init='random',random_state=0)
km1.fit(p_df)
# Out:
# KMeans(init='random', n_clusters=5, random_state=0)

# %%
cluster_centers_km1 = km1.cluster_centers_
cluster_centers_km1
# Out:
# array([[ 2.20291993, -0.19787821],
#        [-2.38376234, -0.50208856],
#        [ 1.42524761,  2.17395183],
#        [-0.70554628,  0.97204577],
#        [ 4.47011591, -0.98962046]])

# %%
label1 = pd.Series(km1.labels_)

# %%
label1
# Out:
# 0       4
# 1       1
# 2       0
# 3       1
# 4       3
#        ..
# 2200    0
# 2201    3
# 2202    0
# 2203    0
# 2204    1
# Length: 2205, dtype: int32

# %%
label1.value_counts()
# Out:
# 1    922
# 3    392
# 0    386
# 4    297
# 2    208
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(p_df[:,0], p_df[:,1], c=label1, cmap='viridis')
plt.scatter(cluster_centers_km1[:, 0], cluster_centers_km1[:, 1], s=50, c='black', marker='+', label='Cluster Centers')
plt.xlabel('PCA_1')
plt.ylabel('PCA_2')
plt.title('K-means Clustering using Euclidean Distance')
plt.show()

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score

silhouette_man = silhouette_score(p_df, label1)
ch_man = calinski_harabasz_score(p_df, label1)

print("Silhouette Score:", silhouette_man)
print("Calinski-Harabasz Index:", ch_man)
# Out:
# Silhouette Score: 0.4809099975990924
# Calinski-Harabasz Index: 3958.693889724621

# %%
data
# Out:
#       Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0          58       635         88              546              172
# 1          38        11          1                6                2
# 2          26       426         49              127              111
# 3          26        11          4               20               10
# 4          94       173         43              118               46
# ...       ...       ...        ...              ...              ...
# 2200       46       709         43              182               42
# 2201       56       406          0               30                0
# 2202       91       908         48              217               32
# 2203        8       428         30              214               80
# 2204       40        84          3               61                2
#
#       MntSweetProducts  MntGoldProds  MntTotal  MntRegularProds  \
# 0                   88            88      1529             1441
# ...

# %%
labels1=pd.DataFrame(label1)
labels1.columns=['label']
labels1
# Out:
#       label
# 0         4
# 1         1
# 2         0
# 3         1
# 4         3
# ...     ...
# 2200      0
# 2201      3
# 2202      0
# 2203      0
# 2204      1
#
# [2205 rows x 1 columns]

# %%
l1_df = pd.concat([labels1, data],axis=True)

# %%
l1_df
# Out:
#       label  Recency  MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# 0         4       58       635         88              546              172
# 1         1       38        11          1                6                2
# 2         0       26       426         49              127              111
# 3         1       26        11          4               20               10
# 4         3       94       173         43              118               46
# ...     ...      ...       ...        ...              ...              ...
# 2200      0       46       709         43              182               42
# 2201      3       56       406          0               30                0
# 2202      0       91       908         48              217               32
# 2203      0        8       428         30              214               80
# 2204      1       40        84          3               61                2
#
# ...

# %% [markdown]
# # ***Visualization***

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, cmap='PiYG')
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
marital_status = df[['marital_Divorced', 'marital_Married', 'marital_Single', 'marital_Together', 'marital_Widow']].sum()
pastel_colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700']
marital_status.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), title='Marital Status Distribution',colors=pastel_colors)
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(data=data[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']],palette='Set3')
plt.title('Violin Plot of Spending on Products')
plt.ylabel('Spending')
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df['Recency'], kde=True, bins=30,color=sns.color_palette("deep")[0])
plt.title('Distribution of Recency')
plt.xlabel('Recency (days since last purchase)')
plt.ylabel('Frequency')
plt.show()

# %%
purchase_types = data[['NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum()
purchase_types.plot(kind='bar', stacked=True, figsize=(10, 6))
sns.set_palette("Accent")
plt.title('Total Purchases by Type')
plt.ylabel('Number of Purchases')
plt.show()

# %% [markdown]
# # ***Insights and Recommendations***

# %% [markdown]
# **Analysis of each segment:**
#
# *Segment 1 (Largest):* Mixed purchasing behavior, high engagement.
# *Recommendation:* Personalized marketing, loyalty programs.
#
# *Segment 3:* Moderate purchases, more online.
# *Recommendation:* Targeted digital campaigns for favorite categories.
#
# Segment 0: High in-store spending on everyday goods.
# *Recommendation:* In-store promotions and enhanced customer service.
#
# *Segment 4:* Fewer, high-value luxury purchases.
# *Recommendation:* Offer exclusive services and cross-sell premium products.
#
# *Segment 2:* Frequent smaller purchases, deal-driven.
# *Recommendation:* Promote discounts and flash sales.
#
# **General Insights:**
#
# Product Bundling: Across segments, customers show interest in specific product categories (e.g., wines, meat). Consider bundling complementary products to increase average order value.
#
# Personalization: Personalizing promotions and outreach based on each segment’s preferences can improve customer satisfaction and loyalty.
#
# Digital Engagement: With segments showing varying preferences for online or store purchases, tailor marketing efforts to optimize the customer journey in both online and physical channels.
